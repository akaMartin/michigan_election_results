# %% [markdown]
# # Michigan Precinct Level Election Results

# %%
#  Notebook to explore and compile historical 
#  and current precinct level election results
#  for analysis and python/gis practice

# %%
import pandas as pd
import numpy as np
import requests 
import os
import zipfile

# %% [markdown]
# ## Grabbing raw data from MI SoS

# %%
#Read the file from website
url='https://miboecfr.nictusa.com/cfr/presults/'
cycle='2020'
file= cycle + 'GEN.zip'
r = requests.get(url + file,  allow_redirects=True)
open('raw_data/2020GEN.zip', 'wb').write(r.content)
# Out:
# 1728080

# %%
with zipfile.ZipFile('raw_data/2020GEN.ZIP') as z:
    print (z.namelist())
# Out:
# ['2020city.txt', '2020name.txt', '2020offc.txt', '2020vote.txt', 'county.txt', 'readme.txt']

# %%
archive = zipfile.ZipFile('raw_data/2020GEN.ZIP')

# %%
with archive.open('readme.txt') as readme:
    for line in readme:
        print (line)
# Out:
# b'2020 Michigan Precinct-Level General Election Results files\r\n'
# b'\r\n'
# b'The file 2020XXX.zip unzips into five files: 2020name.txt, 2020offc.txt,\r\n'
# b'2020vote.txt, 2020city.txt & county.txt. Once unzipped these files will \r\n'
# b'take up approx. 20meg of hard disk space. The files are TAB-delimited. \r\n'
# b'\r\n'
# b'The file layout for the names file is as follows:\r\n'
# b'\r\n'
# b'Field#1:  Election Year\t(PK)\tNumeric\r\n'
# b'Field#2:  Election Type\t(PK)\tText maxlen=3 (PRI=Primary,GEN=General)\r\n'
# b'Field#3:  Office Code\t(PK)\tNumeric\r\n'
# b'\r\n'
# b'           1 President of the United States\r\n'
# b'           2 Governor\r\n'
# b'           3 Secretary of State\r\n'
# b'           4 Attorney General\r\n'
# b'           5 United States Senator\r\n'
# b'           6 U.S. Representative in Congress\r\n'
# b'           7 State Senator\r\n'
# b'           8 State Representative\r\n'
# b'           9 Member of the State Board of Education\r\n'
# b'          10 Member of the University of Michigan Board of Regents\r\n'
# b'          11 Member of the Michigan State University Board of Trustees\r\n'
# b'          12 Member of the Wayne State University Board of Governors\r\n'
# b'          13 Justice of the Supreme Court\r\n'
# b'          90 Statewide Ballot Proposals\r\n'
# b'\t\t \r\n'
# b'Field#4:  District Code\t(PK)\tText maxlen=5 (Make sure imports as Text!)\r\n'
# b'\r\n'
# b'\t\t  Reference Office Description in offices file.\r\n'
# b'\r\n'
# b'Field#5:  Status Code\t(PK)\tNumeric (Included in offices file)\r\n'
# b'\r\n'
# b'          0    Regular Term\r\n'
# b'          1    Non-Incumbent\r\n'
# b'          2-4  Incumbent - Partial Term\r\n'
# b'          5-7  Non-Incumbent - Partial Term\r\n'
# b'          8    Partial Term\r\n'
# b'          9-10 New Judgeship\r\n'
# b'\r\n'
# b'Field#6:  Candidate ID#\t(PK)\tNumeric (includes some negative numbers)\r\n'
# b'Field#7:  Candidate Last Name\tText maxlen=40\r\n'
# b'Field#8:  Candidate First Name\tText maxlen=32\r\n'
# b'Field#9:  Candidate Middle Name\tText maxlen=32\r\n'
# b'Field#10: Candidate Party Name\tText maxlen=5 (new field in 2008)\r\n'
# b'\r\n'
# b'          DEM        Democratic Party\r\n'
# b'          GRN        Green Party\r\n'
# b'          LIB        Libertarian Party\r\n'
# b'          NLP        Natural Law Party\r\n'
# b'          NPA        No Party Affiliation\r\n'
# b'          REP        Republican Party\r\n'
# b'          RFP        Reform Party\r\n'
# b'          TIS        TIS\r\n'
# b'          UST        US Taxpayers\r\n'
# b'          WORW       Workers World\r\n'
# b'\r\n'
# b'The file layout for the offices file is as follows:\r\n'
# b'\r\n'
# b'Field#1:  Election Year\t(PK)\tSee above*\r\n'
# b'Field#2:  Election Type\t(PK)\tSee above*\r\n'
# b'Field#3:  Office Code\t(PK)\tSee above*\r\n'
# b'Field#4:  District Code\t(PK)\tSee above* (Make sure imports as Text!)\r\n'
# b'Field#5:  Status Code\t(PK)\tSee above*\r\n'
# b'Field#6:  Office Description \tText maxlen=255\r\n'
# b'\r\n'
# b'          Detailed description of the combination of the Office Code,\r\n'
# b'          District Code and Status Code fields, including the number\r\n'
# b'          of open positions within the office and where the candidate\r\n'
# b'          may have filed.\r\n'
# b'\r\n'
# b'* Fields shared between offices and other files. Used to "join" or \r\n'
# b'  link information together.\r\n'
# b'\r\n'
# b'The file layout for the votes file is as follows:\r\n'
# b'\r\n'
# b'Field#1:  Election Year\t (PK)See above*\r\n'
# b'Field#2:  Election Type\t (PK)See above*\r\n'
# b'Field#3:  Office Code\t (PK)See above*\r\n'
# b'Field#4:  District Code\t (PK)See above* (Make sure imports as Text!)\r\n'
# b'Field#5:  Status Code\t (PK)See above*\r\n'
# b'Field#6:  Candidate ID#\t (PK)See above*\r\n'
# b'Field#7:  County Code\t (PK)Numeric (See county.txt)\r\n'
# b'Field#8:  City/Town Code (PK)Numeric (See cities file)\r\n'
# b'Field#9:  Ward Number\t (PK)Numeric (Zero-filled if not applicable)\r\n'
# b'Field#10: Precinct Number(PK)Numeric (>=900=Absent Voter Counting Board)\r\n'
# b'Field#11: Precinct Label (PK)Text maxlen=10 (AVCB=Absent Voter Counting Board)\r\n'
# b'Field#12: Precinct #Votes    Numeric (Poll Book Totals if Office Code=0)\r\n'
# b'\r\n'
# b'* Fields shared between both names and votes files. Used to "join" or \r\n'
# b'  link information together.\r\n'
# b'\r\n'
# b'The file layout for the cities file is as follows:\r\n'
# b'\r\n'
# b'Field#1:  Election Year\t(PK)\t\tSee above*\r\n'
# b'Field#2:  Election Type\t(PK)\t\tSee above*\r\n'
# b'Field#3:  County Code\t(PK)\t\tSee above*\r\n'
# b'Field#4:  City/Township Code(PK)\tSee above*\r\n'
# b'Field#5:  City/Township Description\tText maxlen=50\r\n'
# b'\r\n'
# b'* Fields shared between cities and other files. Used to "join" or \r\n'
# b'  link information together.\r\n'
# b'\r\n'
# b'The file layout for the county file is as follows:\r\n'
# b'\r\n'
# b'Field#1   County Code\t(PK)\tSee above*\r\n'
# b'Field#2   County Name\t\t\tText maxlen=64\r\n'
# b'\r\n'
# b'* Fields shared between county and other files. Used to "join" or \r\n'
# b'  link information together.\r\n'
# b'\r\n'
# b'Hints & Tips\r\n'
# b'\r\n'
# b'(PK) Primary Keys are unique by definition and not absolutely necessary\r\n'
# b'to obtain what you want from this data. They are only suggestions.\r\n'
# b'\r\n'
# b'You may choose to ignore/eliminate the Election Year/Type fields\r\n'
# b'throughout if you find them redundant, however, if you do not eliminate\r\n'
# b'them, (or at least one of them) upon import of the votes table, the \r\n'
# b'suggested Primary Key will not work in products such as Access that \r\n'
# b'limit the number of fields in a Primary Key to ten.\r\n'
# b' \r\n'
# b'Two composite indexes are suggested for the votes table, regardless of\r\n'
# b'whether or not you choose to use Primary Keys:\r\n'
# b'\r\n'
# b'Key#1: Election Year,\r\n'
# b'       Election Type,\r\n'
# b'       Office Code,\r\n'
# b'       District Code,\r\n'
# b'       Status Code,\r\n'
# b'       Candidate ID#\r\n'
# b'\t\r\n'
# b'Key#2: Election Year,\r\n'
# b'       Election Type,\r\n'
# b'       County Code,\r\n'
# b'       City/Town Code\r\n'
# b'\r\n'
# b'Eliminate any fields from the above keys if you have chosen not to import them.\r\n'
# b'\r\n'
# b'Any questions regarding this information can be directed to the Michigan\r\n'
# b'Bureau of Elections by calling (517) 335-3234.\r\n'

# %%
# Build some keys for column names 
names_columns = ['cycle',
  'election_type',
  'office_code',
  'district_code',
  'status_code',
  'candidate_id',
  'candidate_last_name',
  'candidate_first_name',
  'candidate_middle_name',
  'candidate_party'
  ]

offices_columns = [
  'cycle',
  'election_type',
  'office_code',
  'district_code',
  'status_code',
  'office_description',
  ]

votes_columns = [
  'cycle',
  'election_type',
  'office_code',
  'district_code',
  'status_code',
  'candidate_id',
  'county_code',
  'juris_code',
  'ward_number',
  'precinct_number',
  'precinct_label',
  'precinct_votes'
  ]

cities_columns = [
  'cycle',
  'election_type',
  'county_code',
  'juris_code',
  'juris_name'
  ]

counties_columns = [
  'county_code',
  'county_name'
  ]

# %%
# Load data from each dictionairy into dataframes
df_counties = pd.read_csv(archive.open('county.txt'),delimiter='\t',names=counties_columns,index_col=False)
df_cities = pd.read_csv(archive.open(cycle + 'city.txt'),delimiter='\t',names=cities_columns,index_col=False)
df_names = pd.read_csv(archive.open(cycle + 'name.txt'),delimiter='\t',names=names_columns,index_col=False)
df_offices = pd.read_csv(archive.open(cycle + 'offc.txt'),delimiter='\t',names=offices_columns,index_col=False)
df_votes = pd.read_csv(archive.open(cycle + 'vote.txt'),delimiter='\t',names=votes_columns,index_col=False)

# %%
df_names
# Out:
#      cycle election_type  office_code  district_code  status_code  \
# 0     2020           GEN            0              0            0
# 1     2020           GEN            1              0            0
# 2     2020           GEN            1              0            0
# 3     2020           GEN            1              0            0
# 4     2020           GEN            1              0            0
# ..     ...           ...          ...            ...          ...
# 375   2020           GEN           13              0            0
# 376   2020           GEN           90              0            1
# 377   2020           GEN           90              0            1
# 378   2020           GEN           90              0            2
# 379   2020           GEN           90              0            2
#
#      candidate_id candidate_last_name candidate_first_name  \
# 0               0
# 1           -1417               WELLS                KASEY
# 2           -1416            HOEFLING                  TOM
# 3           -1415              HUNTER           TARA RENEE
# 4           -1414             CARROLL                BRIAN
# ..            ...                 ...                  ...
# 375        519848              MORGAN                KERRY
# 376         -1406                  NO                  NaN
# 377         -1405                 YES                  NaN
# 378         -1408                  NO                  NaN
# 379         -1407                 YES                  NaN
#
#     candidate_middle_name candidate_party
# 0
# 1                     NaN             NPA
# 2                     NaN             NPA
# 3                     NaN             NPA
# 4                      T.             NPA
# ..                    ...             ...
# 375                   LEE             NPA
# 376                   NaN             NPA
# 377                   NaN             NPA
# 378                   NaN             NPA
# 379                   NaN             NPA
#
# [380 rows x 10 columns]

# %% [markdown]
# ## Building Combined Dataframe

# %%
df_results = df_votes.merge(
        df_counties,on='county_code').merge(
            df_cities[['county_code','juris_code','juris_name']],on=['county_code','juris_code']).merge(
                df_offices[['office_code','district_code','status_code','office_description']], on=['office_code','district_code','status_code']).merge(
                    df_names[['office_code','district_code','status_code','candidate_id','candidate_first_name','candidate_middle_name','candidate_party']],on=['office_code','district_code','status_code','candidate_id'])

# %%
df_results
#369676 Rows (Check to avoid duplicates)
# Out:
#         cycle election_type  office_code  district_code  status_code  \
# 0        2020           GEN            0              0            0
# 1        2020           GEN            0              0            0
# 2        2020           GEN            0              0            0
# 3        2020           GEN            0              0            0
# 4        2020           GEN            0              0            0
# ...       ...           ...          ...            ...          ...
# 369671   2020           GEN            8           1600            0
# 369672   2020           GEN            8           1600            0
# 369673   2020           GEN            8           1600            0
# 369674   2020           GEN            8           1600            0
# 369675   2020           GEN            8           1600            0
#
#         candidate_id  county_code  juris_code  ward_number  precinct_number  \
# 0                  0            1           2            0                1
# 1                  0            1           4            0                1
# 2                  0            1           6            0                1
# 3                  0            1           8            0                1
# 4                  0            1          10            0                1
# ...              ...          ...         ...          ...              ...
# 369671        519762           82          97            0               37
# 369672        519762           82          97            0               38
# 369673        519762           82          97            0               39
# 369674        519762           82          97            0               40
# 369675        519762           82          97            0               41
#
#        precinct_label  precinct_votes county_name          juris_name  \
# 0                 NaN             822      ALCONA     ALCONA TOWNSHIP
# 1                 NaN             761      ALCONA  CALEDONIA TOWNSHIP
# 2                 NaN             733      ALCONA     CURTIS TOWNSHIP
# 3                 NaN             878      ALCONA  GREENBUSH TOWNSHIP
# 4                 NaN             442      ALCONA     GUSTIN TOWNSHIP
# ...               ...             ...         ...                 ...
# 369671            NaN             501       WAYNE       WESTLAND CITY
# 369672            NaN             410       WAYNE       WESTLAND CITY
# 369673            NaN             174       WAYNE       WESTLAND CITY
# 369674            NaN             348       WAYNE       WESTLAND CITY
# 369675            NaN             200       WAYNE       WESTLAND CITY
#
#                                        office_description  \
# 0                         POLL BOOK TOTALS (TOTAL VOTERS)
# 1                         POLL BOOK TOTALS (TOTAL VOTERS)
# 2                         POLL BOOK TOTALS (TOTAL VOTERS)
# 3                         POLL BOOK TOTALS (TOTAL VOTERS)
# 4                         POLL BOOK TOTALS (TOTAL VOTERS)
# ...                                                   ...
# 369671  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369672  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369673  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369674  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369675  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
#
#        candidate_first_name candidate_middle_name candidate_party
# 0
# 1
# 2
# 3
# 4
# ...                     ...                   ...             ...
# 369671                EMILY                   NaN             REP
# 369672                EMILY                   NaN             REP
# 369673                EMILY                   NaN             REP
# 369674                EMILY                   NaN             REP
# 369675                EMILY                   NaN             REP
#
# [369676 rows x 18 columns]

# %%
#Drop pollbook totals lines
df_results=df_results[df_results['office_description']!='POLL BOOK TOTALS (TOTAL VOTERS)']
df_results
# Out:
#         cycle election_type  office_code  district_code  status_code  \
# 4897     2020           GEN            1              0            0
# 4898     2020           GEN            1              0            0
# 4899     2020           GEN            1              0            0
# 4900     2020           GEN            1              0            0
# 4901     2020           GEN            1              0            0
# ...       ...           ...          ...            ...          ...
# 369671   2020           GEN            8           1600            0
# 369672   2020           GEN            8           1600            0
# 369673   2020           GEN            8           1600            0
# 369674   2020           GEN            8           1600            0
# 369675   2020           GEN            8           1600            0
#
#         candidate_id  county_code  juris_code  ward_number  precinct_number  \
# 4897           -1417            1           2            0                1
# 4898           -1417            1           4            0                1
# 4899           -1417            1           6            0                1
# 4900           -1417            1           8            0                1
# 4901           -1417            1          10            0                1
# ...              ...          ...         ...          ...              ...
# 369671        519762           82          97            0               37
# 369672        519762           82          97            0               38
# 369673        519762           82          97            0               39
# 369674        519762           82          97            0               40
# 369675        519762           82          97            0               41
#
#        precinct_label  precinct_votes county_name          juris_name  \
# 4897              NaN               0      ALCONA     ALCONA TOWNSHIP
# 4898              NaN               0      ALCONA  CALEDONIA TOWNSHIP
# 4899              NaN               0      ALCONA     CURTIS TOWNSHIP
# 4900              NaN               0      ALCONA  GREENBUSH TOWNSHIP
# 4901              NaN               0      ALCONA     GUSTIN TOWNSHIP
# ...               ...             ...         ...                 ...
# 369671            NaN             501       WAYNE       WESTLAND CITY
# 369672            NaN             410       WAYNE       WESTLAND CITY
# 369673            NaN             174       WAYNE       WESTLAND CITY
# 369674            NaN             348       WAYNE       WESTLAND CITY
# 369675            NaN             200       WAYNE       WESTLAND CITY
#
#                                        office_description  \
# 4897    PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# 4898    PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# 4899    PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# 4900    PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# 4901    PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# ...                                                   ...
# 369671  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369672  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369673  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369674  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369675  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
#
#        candidate_first_name candidate_middle_name candidate_party
# 4897                  KASEY                   NaN             NPA
# 4898                  KASEY                   NaN             NPA
# 4899                  KASEY                   NaN             NPA
# 4900                  KASEY                   NaN             NPA
# 4901                  KASEY                   NaN             NPA
# ...                     ...                   ...             ...
# 369671                EMILY                   NaN             REP
# 369672                EMILY                   NaN             REP
# 369673                EMILY                   NaN             REP
# 369674                EMILY                   NaN             REP
# 369675                EMILY                   NaN             REP
#
# [364779 rows x 18 columns]

# %%
#Adding Unified Office Names
def office_names(row):
    if row['office_code']==1:
        return 'President of the United States'
    elif row['office_code']==2:
        return 'Governor'
    elif row['office_code']==3:
        return 'Secretary of State'
    elif row['office_code']==4:
        return 'Attorney General'
    elif row['office_code']==5:
        return 'United States Senator'
    elif row['office_code']==6:
        return 'U.S. Representative in Congress'
    elif row['office_code']==7:
        return 'State Senator'
    elif row['office_code']==8:
        return 'State Representative'
    elif row['office_code']==9:
        return 'Member of the State Board of Education'
    elif row['office_code']==10:
        return 'Member of the University of Michigan Board of Regents'
    elif row['office_code']==11:
        return 'Member of the Michigan State University Board of Trustees'
    elif row['office_code']==12:
        return 'Member of the Wayne State University Board of Governors'
    elif row['office_code']==13:
        return 'Justice of the Supreme Court'
    elif row['office_code']==90:
        return 'Statewide Ballot Proposals'

df_results['office_name']=df_results.apply(office_names, axis=1)
# Out:
# <ipython-input-13-4ce488a145d8>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_results['office_name']=df_results.apply(office_names, axis=1)

# %%
df_results
# Out:
#         cycle election_type  office_code  district_code  status_code  \
# 4897     2020           GEN            1              0            0
# 4898     2020           GEN            1              0            0
# 4899     2020           GEN            1              0            0
# 4900     2020           GEN            1              0            0
# 4901     2020           GEN            1              0            0
# ...       ...           ...          ...            ...          ...
# 369671   2020           GEN            8           1600            0
# 369672   2020           GEN            8           1600            0
# 369673   2020           GEN            8           1600            0
# 369674   2020           GEN            8           1600            0
# 369675   2020           GEN            8           1600            0
#
#         candidate_id  county_code  juris_code  ward_number  precinct_number  \
# 4897           -1417            1           2            0                1
# 4898           -1417            1           4            0                1
# 4899           -1417            1           6            0                1
# 4900           -1417            1           8            0                1
# 4901           -1417            1          10            0                1
# ...              ...          ...         ...          ...              ...
# 369671        519762           82          97            0               37
# 369672        519762           82          97            0               38
# 369673        519762           82          97            0               39
# 369674        519762           82          97            0               40
# 369675        519762           82          97            0               41
#
#        precinct_label  precinct_votes county_name          juris_name  \
# 4897              NaN               0      ALCONA     ALCONA TOWNSHIP
# 4898              NaN               0      ALCONA  CALEDONIA TOWNSHIP
# 4899              NaN               0      ALCONA     CURTIS TOWNSHIP
# 4900              NaN               0      ALCONA  GREENBUSH TOWNSHIP
# 4901              NaN               0      ALCONA     GUSTIN TOWNSHIP
# ...               ...             ...         ...                 ...
# 369671            NaN             501       WAYNE       WESTLAND CITY
# 369672            NaN             410       WAYNE       WESTLAND CITY
# 369673            NaN             174       WAYNE       WESTLAND CITY
# 369674            NaN             348       WAYNE       WESTLAND CITY
# 369675            NaN             200       WAYNE       WESTLAND CITY
#
#                                        office_description  \
# 4897    PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# 4898    PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# 4899    PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# 4900    PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# 4901    PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# ...                                                   ...
# 369671  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369672  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369673  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369674  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369675  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
#
#        candidate_first_name candidate_middle_name candidate_party  \
# 4897                  KASEY                   NaN             NPA
# 4898                  KASEY                   NaN             NPA
# 4899                  KASEY                   NaN             NPA
# 4900                  KASEY                   NaN             NPA
# 4901                  KASEY                   NaN             NPA
# ...                     ...                   ...             ...
# 369671                EMILY                   NaN             REP
# 369672                EMILY                   NaN             REP
# 369673                EMILY                   NaN             REP
# 369674                EMILY                   NaN             REP
# 369675                EMILY                   NaN             REP
#
#                            office_name
# 4897    President of the United States
# 4898    President of the United States
# 4899    President of the United States
# 4900    President of the United States
# 4901    President of the United States
# ...                                ...
# 369671            State Representative
# 369672            State Representative
# 369673            State Representative
# 369674            State Representative
# 369675            State Representative
#
# [364779 rows x 19 columns]

# %%
def party_names(row):
    if row['candidate_party']=='DEM':
        return 'Democratic'
    elif row['candidate_party']=='GRN':
        return 'Green'
    elif row['candidate_party']=='LIB':
        return 'Libertarian'
    elif row['candidate_party']=='NLP':
        return 'Natural Law'
    elif row['candidate_party']=='NPA':
        return 'No Party Affiliation'
    elif row['candidate_party']=='REP':
        return 'Republican'
    elif row['candidate_party']=='RFP':
        return 'Reform'
    elif row['candidate_party']=='TIS':
        return 'TIS'
    elif row['candidate_party']=='UST':
        return 'US Taxpayers'
    elif row['candidate_party']=='WORW':
        return 'Workers World'

df_results['party_name']=df_results.apply(party_names, axis=1)
# Out:
# <ipython-input-15-9e14faaaf84a>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_results['party_name']=df_results.apply(party_names, axis=1)

# %%
df_results
# Out:
#         cycle election_type  office_code  district_code  status_code  \
# 4897     2020           GEN            1              0            0
# 4898     2020           GEN            1              0            0
# 4899     2020           GEN            1              0            0
# 4900     2020           GEN            1              0            0
# 4901     2020           GEN            1              0            0
# ...       ...           ...          ...            ...          ...
# 369671   2020           GEN            8           1600            0
# 369672   2020           GEN            8           1600            0
# 369673   2020           GEN            8           1600            0
# 369674   2020           GEN            8           1600            0
# 369675   2020           GEN            8           1600            0
#
#         candidate_id  county_code  juris_code  ward_number  precinct_number  \
# 4897           -1417            1           2            0                1
# 4898           -1417            1           4            0                1
# 4899           -1417            1           6            0                1
# 4900           -1417            1           8            0                1
# 4901           -1417            1          10            0                1
# ...              ...          ...         ...          ...              ...
# 369671        519762           82          97            0               37
# 369672        519762           82          97            0               38
# 369673        519762           82          97            0               39
# 369674        519762           82          97            0               40
# 369675        519762           82          97            0               41
#
#        precinct_label  precinct_votes county_name          juris_name  \
# 4897              NaN               0      ALCONA     ALCONA TOWNSHIP
# 4898              NaN               0      ALCONA  CALEDONIA TOWNSHIP
# 4899              NaN               0      ALCONA     CURTIS TOWNSHIP
# 4900              NaN               0      ALCONA  GREENBUSH TOWNSHIP
# 4901              NaN               0      ALCONA     GUSTIN TOWNSHIP
# ...               ...             ...         ...                 ...
# 369671            NaN             501       WAYNE       WESTLAND CITY
# 369672            NaN             410       WAYNE       WESTLAND CITY
# 369673            NaN             174       WAYNE       WESTLAND CITY
# 369674            NaN             348       WAYNE       WESTLAND CITY
# 369675            NaN             200       WAYNE       WESTLAND CITY
#
#                                        office_description  \
# 4897    PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# 4898    PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# 4899    PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# 4900    PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# 4901    PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# ...                                                   ...
# 369671  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369672  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369673  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369674  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369675  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
#
#        candidate_first_name candidate_middle_name candidate_party  \
# 4897                  KASEY                   NaN             NPA
# 4898                  KASEY                   NaN             NPA
# 4899                  KASEY                   NaN             NPA
# 4900                  KASEY                   NaN             NPA
# 4901                  KASEY                   NaN             NPA
# ...                     ...                   ...             ...
# 369671                EMILY                   NaN             REP
# 369672                EMILY                   NaN             REP
# 369673                EMILY                   NaN             REP
# 369674                EMILY                   NaN             REP
# 369675                EMILY                   NaN             REP
#
#                            office_name            party_name
# 4897    President of the United States  No Party Affiliation
# 4898    President of the United States  No Party Affiliation
# 4899    President of the United States  No Party Affiliation
# 4900    President of the United States  No Party Affiliation
# 4901    President of the United States  No Party Affiliation
# ...                                ...                   ...
# 369671            State Representative            Republican
# 369672            State Representative            Republican
# 369673            State Representative            Republican
# 369674            State Representative            Republican
# 369675            State Representative            Republican
#
# [364779 rows x 20 columns]

# %%
def statuses(row):
    if row['status_code']==0:
        return 'Regular Term'
    elif row['status_code']==1:
        return 'Non-Incumbent'
    elif (row['status_code']>=2) & (row['status_code']<=4):
        return 'Incumbent - Partial Term'
    elif (row['status_code']>=5) & (row['status_code']<=7):
        return 'Non-Incumbent - Partial Term'
    elif row['status_code']==8:
        return 'Partial Term'
    elif (row['status_code']>=9) & (row['status_code']<=10):
        return 'New Judgeship'

def is_partial(row):
    if (row['status_code']>=2) & (row['status_code']<=8):
        return True
    else:
        return False

df_results['status_name']=df_results.apply(statuses, axis=1)
df_results['is_partial']=df_results.apply(is_partial, axis=1)
# Out:
# <ipython-input-17-9471dfb5af0d>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_results['status_name']=df_results.apply(statuses, axis=1)
# <ipython-input-17-9471dfb5af0d>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_results['is_partial']=df_results.apply(is_partial, axis=1)

# %%
df_results
# Out:
#         cycle election_type  office_code  district_code  status_code  \
# 4897     2020           GEN            1              0            0
# 4898     2020           GEN            1              0            0
# 4899     2020           GEN            1              0            0
# 4900     2020           GEN            1              0            0
# 4901     2020           GEN            1              0            0
# ...       ...           ...          ...            ...          ...
# 369671   2020           GEN            8           1600            0
# 369672   2020           GEN            8           1600            0
# 369673   2020           GEN            8           1600            0
# 369674   2020           GEN            8           1600            0
# 369675   2020           GEN            8           1600            0
#
#         candidate_id  county_code  juris_code  ward_number  precinct_number  \
# 4897           -1417            1           2            0                1
# 4898           -1417            1           4            0                1
# 4899           -1417            1           6            0                1
# 4900           -1417            1           8            0                1
# 4901           -1417            1          10            0                1
# ...              ...          ...         ...          ...              ...
# 369671        519762           82          97            0               37
# 369672        519762           82          97            0               38
# 369673        519762           82          97            0               39
# 369674        519762           82          97            0               40
# 369675        519762           82          97            0               41
#
#         ... county_name          juris_name  \
# 4897    ...      ALCONA     ALCONA TOWNSHIP
# 4898    ...      ALCONA  CALEDONIA TOWNSHIP
# 4899    ...      ALCONA     CURTIS TOWNSHIP
# 4900    ...      ALCONA  GREENBUSH TOWNSHIP
# 4901    ...      ALCONA     GUSTIN TOWNSHIP
# ...     ...         ...                 ...
# 369671  ...       WAYNE       WESTLAND CITY
# 369672  ...       WAYNE       WESTLAND CITY
# 369673  ...       WAYNE       WESTLAND CITY
# 369674  ...       WAYNE       WESTLAND CITY
# 369675  ...       WAYNE       WESTLAND CITY
#
#                                        office_description  \
# 4897    PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# 4898    PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# 4899    PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# 4900    PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# 4901    PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# ...                                                   ...
# 369671  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369672  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369673  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369674  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369675  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
#
#        candidate_first_name candidate_middle_name candidate_party  \
# 4897                  KASEY                   NaN             NPA
# 4898                  KASEY                   NaN             NPA
# 4899                  KASEY                   NaN             NPA
# 4900                  KASEY                   NaN             NPA
# 4901                  KASEY                   NaN             NPA
# ...                     ...                   ...             ...
# 369671                EMILY                   NaN             REP
# 369672                EMILY                   NaN             REP
# 369673                EMILY                   NaN             REP
# 369674                EMILY                   NaN             REP
# 369675                EMILY                   NaN             REP
#
#                            office_name            party_name   status_name  \
# 4897    President of the United States  No Party Affiliation  Regular Term
# 4898    President of the United States  No Party Affiliation  Regular Term
# 4899    President of the United States  No Party Affiliation  Regular Term
# 4900    President of the United States  No Party Affiliation  Regular Term
# 4901    President of the United States  No Party Affiliation  Regular Term
# ...                                ...                   ...           ...
# 369671            State Representative            Republican  Regular Term
# 369672            State Representative            Republican  Regular Term
# 369673            State Representative            Republican  Regular Term
# 369674            State Representative            Republican  Regular Term
# 369675            State Representative            Republican  Regular Term
#
#        is_partial
# 4897        False
# 4898        False
# 4899        False
# 4900        False
# 4901        False
# ...           ...
# 369671      False
# 369672      False
# 369673      False
# 369674      False
# 369675      False
#
# [364779 rows x 22 columns]

# %% [markdown]
# ## Build District Columns for Congress, State House

# %%
# Create a precinct ID

codes = ['county_code','juris_code','ward_number','precinct_number']
lens = [2,4,2,3]
i=0
for c in codes:
    df_results[c]=df_results[c].astype(str)
    df_results[c]=df_results[c].str.zfill(lens[i])
    i += 1

df_results['precinct_id']= df_results['county_code'] + df_results['juris_code'] + df_results['ward_number'] + df_results['precinct_number']
# Out:
# <ipython-input-21-197a771a3f6f>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_results[c]=df_results[c].astype(str)
# <ipython-input-21-197a771a3f6f>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_results[c]=df_results[c].str.zfill(lens[i])
# <ipython-input-21-197a771a3f6f>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_results['precinct_id']= df_results['county_code'] + df_results['juris_code'] + df_results['ward_number'] + df_results['precinct_number']

# %%
df_results
# Out:
#         cycle election_type  office_code  district_code  status_code  \
# 4897     2020           GEN            1              0            0
# 4898     2020           GEN            1              0            0
# 4899     2020           GEN            1              0            0
# 4900     2020           GEN            1              0            0
# 4901     2020           GEN            1              0            0
# ...       ...           ...          ...            ...          ...
# 369671   2020           GEN            8           1600            0
# 369672   2020           GEN            8           1600            0
# 369673   2020           GEN            8           1600            0
# 369674   2020           GEN            8           1600            0
# 369675   2020           GEN            8           1600            0
#
#         candidate_id county_code juris_code ward_number precinct_number  ...  \
# 4897           -1417          01       0002          00             001  ...
# 4898           -1417          01       0004          00             001  ...
# 4899           -1417          01       0006          00             001  ...
# 4900           -1417          01       0008          00             001  ...
# 4901           -1417          01       0010          00             001  ...
# ...              ...         ...        ...         ...             ...  ...
# 369671        519762          82       0097          00             037  ...
# 369672        519762          82       0097          00             038  ...
# 369673        519762          82       0097          00             039  ...
# 369674        519762          82       0097          00             040  ...
# 369675        519762          82       0097          00             041  ...
#
#                 juris_name                                 office_description  \
# 4897       ALCONA TOWNSHIP  PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# 4898    CALEDONIA TOWNSHIP  PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# 4899       CURTIS TOWNSHIP  PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# 4900    GREENBUSH TOWNSHIP  PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# 4901       GUSTIN TOWNSHIP  PRESIDENT OF THE UNITED STATES 4 YEAR TERM (1)...
# ...                    ...                                                ...
# 369671       WESTLAND CITY  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369672       WESTLAND CITY  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369673       WESTLAND CITY  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369674       WESTLAND CITY  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
# 369675       WESTLAND CITY  16TH DISTRICT REPRESENTATIVE IN STATE LEGISLAT...
#
#        candidate_first_name candidate_middle_name candidate_party  \
# 4897                  KASEY                   NaN             NPA
# 4898                  KASEY                   NaN             NPA
# 4899                  KASEY                   NaN             NPA
# 4900                  KASEY                   NaN             NPA
# 4901                  KASEY                   NaN             NPA
# ...                     ...                   ...             ...
# 369671                EMILY                   NaN             REP
# 369672                EMILY                   NaN             REP
# 369673                EMILY                   NaN             REP
# 369674                EMILY                   NaN             REP
# 369675                EMILY                   NaN             REP
#
#                            office_name            party_name   status_name  \
# 4897    President of the United States  No Party Affiliation  Regular Term
# 4898    President of the United States  No Party Affiliation  Regular Term
# 4899    President of the United States  No Party Affiliation  Regular Term
# 4900    President of the United States  No Party Affiliation  Regular Term
# 4901    President of the United States  No Party Affiliation  Regular Term
# ...                                ...                   ...           ...
# 369671            State Representative            Republican  Regular Term
# 369672            State Representative            Republican  Regular Term
# 369673            State Representative            Republican  Regular Term
# 369674            State Representative            Republican  Regular Term
# 369675            State Representative            Republican  Regular Term
#
#        is_partial  precinct_id
# 4897        False  01000200001
# 4898        False  01000400001
# 4899        False  01000600001
# 4900        False  01000800001
# 4901        False  01001000001
# ...           ...          ...
# 369671      False  82009700037
# 369672      False  82009700038
# 369673      False  82009700039
# 369674      False  82009700040
# 369675      False  82009700041
#
# [364779 rows x 23 columns]
